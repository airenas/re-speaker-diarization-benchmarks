# %%
from pyannote.core import Segment
file="MLNG001"
segment = Segment(0, 100)

# %%
from pyannote.core import Segment, notebook
from pyannote.database.util import load_rttm
_, groundtruth = load_rttm(f'../../corpus/audio/{file}.rrtm').popitem()
notebook.crop = None
# visualize groundtruth
groundtruth

# %%
_, groundtruth = load_rttm(f'../../corpus/audio/{file}.rrtm').popitem()
notebook.crop = segment
groundtruth

# %%
_, groundtruth = load_rttm(f'../../work/pyannote/{file}.rrtm').popitem()
notebook.crop = segment
groundtruth

# %%
_, groundtruth = load_rttm(f'../../work/lium/{file}.rrtm').popitem()
notebook.crop = segment
groundtruth
