# %%
from pyannote.core import Segment, notebook
from pyannote.database.util import load_rttm
_, groundtruth = load_rttm('../../work/audio/WAV16/ADVK/ADVK001.rrtm').popitem()
notebook.crop = None
# visualize groundtruth
groundtruth

# %%
from pyannote.core import Segment, notebook
segment = Segment(270, 300)
_, groundtruth = load_rttm('../../work/audio/WAV16/ADVK/ADVK001.rrtm').popitem()
notebook.crop = segment
groundtruth

# %%
from pyannote.core import Segment, notebook
from pyannote.database.util import load_rttm
_, groundtruth = load_rttm('../../work/audio/WAV16/ADVK/ADVK001.wav.rrtm').popitem()
notebook.crop = segment
groundtruth
